# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# %%
d10_sorted = torch.load(r"C:\Users\rahar\Files\ML research\Proteins\nano_fold\mid_semester\ssm_10_delay_5_sorted.pt",
					   map_location=torch.device('cpu'))

d10_unsorted = torch.load(r"C:\Users\rahar\Files\ML research\Proteins\nano_fold\mid_semester\ssm_10_delay_5_unsorted.pt",
					   map_location=torch.device('cpu'))

d5_sorted = torch.load(r"C:\Users\rahar\Files\ML research\Proteins\nano_fold\mid_semester\ssm_5_delay_5_sorted.pt",
					   map_location=torch.device('cpu'))

d5_unsorted = torch.load(r"C:\Users\rahar\Files\ML research\Proteins\nano_fold\mid_semester\ssm_5_delay_5_unsorted.pt",
					   map_location=torch.device('cpu'))
# Out:
# C:\Users\rahar\AppData\Local\Temp\ipykernel_44992\49414669.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
harmonic =  torch.load(r"C:\Users\rahar\Files\ML research\Proteins\nano_fold\mid_semester\ssm_5_delay_5_unsorted_harmonic_1.pt",
					   map_location=torch.device('cpu'))

sidewyas = torch.load(r"C:\Users\rahar\Files\ML research\Proteins\nano_fold\mid_semester\ssm__delay_5_sorted.pt",
					   map_location=torch.device('cpu'))
# Out:
# C:\Users\rahar\AppData\Local\Temp\ipykernel_44992\1767082952.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
color_10 = "blue"
color_5 = "orange"
style_sorted = '-'
style_unsorted = '--'

# Plot each line with appropriate color and style
plt.plot(d10_sorted["training_accuracies"], color=color_10, linestyle=style_sorted, label="10 sorted")
plt.plot(d10_unsorted["training_accuracies"], color=color_10, linestyle=style_unsorted, label="10 unsorted")
plt.plot(d5_sorted["training_accuracies"], color=color_5, linestyle=style_sorted, label="5 sorted")
plt.plot(d5_unsorted["training_accuracies"], color=color_5, linestyle=style_unsorted, label="5 unsorted")
plt.plot(sidewyas["training_accuracies"], color="black", linestyle=style_sorted, label="sideways")

# Adding legend and labels
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Training Accuracy")

plt.show()

# %% [markdown]
# - Debugging the sorted MNIST things?
#   - I just don't see why there would be a bug caused from sorting or grouping, but who knows
# - Check the cosine alignment inside the batch
#   - Good metric
# - Add a cosine scheduler
#   - For sure, it will help
# - Check binary with MNIST
# - maybe combine with some other learning rule
# - predictive coding

# %% [markdown]
# - for videos, use surprise storage gradients
#   - zero out a bunch of gradients (if the prediction is fine then don't do updates)
#   - only do updates for very important gradients

# %%
2**50
# Out:
# 1125899906842624

# %%
plt.plot(d5_unsorted["training_accuracies"],label="no harmonics")
plt.plot(d10_unsorted["training_accuracies"],label="ssm 10")
plt.plot(harmonic["training_accuracies"],label="harmonics")
plt.legend()
plt.xlim([0,len(harmonic["training_accuracies"])])
# Out:
# (0.0, 25.0)
